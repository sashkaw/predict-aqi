# %%
# Date: Jan 9, 2022
# Author: Sashka Warner
# Desc: 
# -- Fetches historical air quality data from OpenWeather API,
# -- Fills gaps in air quality data based on averages for a given timestep, 
# -- Summarizes data by daily maximum values
# -- Creates and trains a Long Short-Term Memory (LSTM) model to predict future air quality
# -- Tunes model hyperparameters such as learning rate, number of epochs, and regularization through iterative experiments
# -- Saves trained model and scaler for use in Django application

# %%
# Imports
import os
import re
from dotenv import load_dotenv
from datetime import datetime, timedelta
import collections
import time
import numpy as np
import pandas as pd
import requests
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import joblib
# Out:
# 2023-01-09 19:22:38.225548: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Load credentials
load_dotenv()
WEATHER_API_KEY = os.getenv('WEATHER_API_KEY')

# Create basic URL for API call
WEATHER_API_URL = 'https://api.openweathermap.org/data/2.5/air_pollution/history'

# %%
def get_data(lat, long, date1, date2):
    '''
    Submits request to API for air quality data filtered based on provided lat, long, start date, and end date.
    Note: Can request max 1000 API calls / day without incurring overages.

    Parameters:
    ------------
    lat: Latitude (decimal degrees)
    long: Longitude (decimal degrees)
    date1: Start date (unix time, UTC time zone), e.g. start=1606488670
    date2: End date (unix time, UTC time zone), e.g. end=1606747870

    Returns:
    ------------
    1) json data from API on successful request, OR
    2) -1 if unsuccessful request

    '''
    # Create url from params
    params = {
        'lat': lat,
        'lon': long,
        'start': date1,
        'end': date2,
        'appid': WEATHER_API_KEY,
    }
    
    try:
        response = requests.get(url=WEATHER_API_URL, params=params)
        return response.json()['list']
    except:
        return -1

# %%
# Specify position
site_lat = 44.026280
site_long = -123.083715

# Specify time range for filtering
d1 = datetime(2017, 1, 1)
d2 = datetime(2022, 12, 31)
# Convert to unix time for api call
d1_unix = int(time.mktime(d1.timetuple()))
d2_unix = int(time.mktime(d2.timetuple()))

# Get air quality data formatted as json based on 
# query parameters
air_quality_json = get_data(
    lat=site_lat, 
    long=-site_long, 
    date1=d1_unix, 
    date2=d2_unix)

# %%
# Convert air quality data to DataFrame
air_quality = pd.json_normalize(air_quality_json)
# Format time stamps
air_quality['dt'] = pd.to_datetime(air_quality['dt'], unit='s')
air_quality.head()
# Out:
#                    dt  main.aqi  components.co  components.no  components.no2  \
# 0 2020-11-25 01:00:00         1         236.99           0.60            3.56
# 1 2020-11-25 02:00:00         1         233.65           0.92            2.87
# 2 2020-11-25 03:00:00         1         223.64           0.91            2.16
# 3 2020-11-25 04:00:00         1         213.62           0.64            1.54
# 4 2020-11-25 05:00:00         1         210.29           0.60            1.56
#
#    components.o3  components.so2  components.pm2_5  components.pm10  \
# 0          66.52            1.97              7.08             8.78
# 1          65.80            1.91              6.16             7.67
# 2          63.66            1.62              4.53             5.74
# 3          67.23            2.71              2.81             3.43
# 4          69.38            3.58              2.30             2.70
#
#    components.nh3
# 0           17.73
# 1           16.97
# 2           13.81
# ...

# %%
# Remove dots from column names
air_quality.columns = air_quality.columns.map(lambda x: re.sub('\.', '_', x))
air_quality.reset_index(drop=True, inplace=True)
air_quality.head()
# Out:
#                    dt  main_aqi  components_co  components_no  components_no2  \
# 0 2020-11-25 01:00:00         1         236.99           0.60            3.56
# 1 2020-11-25 02:00:00         1         233.65           0.92            2.87
# 2 2020-11-25 03:00:00         1         223.64           0.91            2.16
# 3 2020-11-25 04:00:00         1         213.62           0.64            1.54
# 4 2020-11-25 05:00:00         1         210.29           0.60            1.56
#
#    components_o3  components_so2  components_pm2_5  components_pm10  \
# 0          66.52            1.97              7.08             8.78
# 1          65.80            1.91              6.16             7.67
# 2          63.66            1.62              4.53             5.74
# 3          67.23            2.71              2.81             3.43
# 4          69.38            3.58              2.30             2.70
#
#    components_nh3
# 0           17.73
# 1           16.97
# 2           13.81
# ...

# %%
# Check types and NAs
for i in air_quality.columns:
    print(i, 'type:', air_quality[i].map(lambda x: type(x)).unique(), 'Has NAs:', any(air_quality[i].isna()))
# Out:
# dt type: [<class 'pandas._libs.tslibs.timestamps.Timestamp'>] Has NAs: False
# main_aqi type: [<class 'int'>] Has NAs: False
# components_co type: [<class 'float'>] Has NAs: False
# components_no type: [<class 'float'>] Has NAs: False
# components_no2 type: [<class 'float'>] Has NAs: False
# components_o3 type: [<class 'float'>] Has NAs: False
# components_so2 type: [<class 'float'>] Has NAs: False
# components_pm2_5 type: [<class 'float'>] Has NAs: False
# components_pm10 type: [<class 'float'>] Has NAs: False
# components_nh3 type: [<class 'float'>] Has NAs: False

# %%
# Examine gaps in time series
air_quality.at[1,'dt'] - air_quality.at[0, 'dt']

# Extract date time column
aq_dates = air_quality['dt']

# Create dict to store unique time deltas
unique_deltas = collections.defaultdict(int)

# Count instances of unique time deltas
for i, val in enumerate(aq_dates):
    if(i > 0):
        t_delta = aq_dates[i] - aq_dates[i-1]
        unique_deltas[t_delta] += 1
        #Examine outliers and their PM2.5 values
        if(t_delta != timedelta(hours=1)):
            print(
                't-1:', aq_dates[i-1], 'PM2.5:', air_quality.at[i-1, 'components_pm2_5'], 
                't:', aq_dates[i], 'PM2.5:', air_quality.at[i, 'components_pm2_5'])
    
unique_deltas
# Out:
# t-1: 2021-01-27 00:00:00 PM2.5: 3.64 t: 2021-01-28 01:00:00 PM2.5: 2.13
# t-1: 2022-01-23 00:00:00 PM2.5: 51.82 t: 2022-01-24 01:00:00 PM2.5: 32.85
# t-1: 2022-02-20 00:00:00 PM2.5: 1.46 t: 2022-02-21 01:00:00 PM2.5: 1.87
# t-1: 2022-07-20 00:00:00 PM2.5: 9.06 t: 2022-07-22 01:00:00 PM2.5: 35.14
# t-1: 2022-12-09 00:00:00 PM2.5: 6.05 t: 2022-12-11 01:00:00 PM2.5: 4.42
# t-1: 2022-12-25 00:00:00 PM2.5: 3.42 t: 2022-12-26 01:00:00 PM2.5: 18.55
# defaultdict(int,
#             {Timedelta('0 days 01:00:00'): 18193,
#              Timedelta('1 days 01:00:00'): 4,
#              Timedelta('2 days 01:00:00'): 2})

# %%
# Create list for filled time steps
fill_steps = []

# Define variable for 1 hr difference
one_hr = timedelta(hours=1)

# Add time steps for gaps in time series
for i, val in enumerate(aq_dates):
    if(i > 0):
        # Create counter for while loop
        # if we need to gap fill the timeseries
        loop_counter = i - 1
        # Get [i-1] timestep
        last_timestep = aq_dates[i-1]
        # Get [i] timestep
        current_timestep = aq_dates[i]
        # Calculate time delta
        t_delta = current_timestep - last_timestep
        
        while(t_delta > one_hr):
            # Add one hour to the [i-1] timestep
            new_timestep = last_timestep + one_hr
            #print(f'Current timestep: {last_timestep}, Adding timestep: {new_timestep}')
            # Add the new timestep to the list
            fill_steps.append(new_timestep)
            # Calculate time delta from [i] timestep
            t_delta = aq_dates[i] - new_timestep
            #print(f't_delta: {t_delta > one_hr}')
            # Increment the counter
            loop_counter += 1
            # Store the current timestep so we can add one hour to 
            # this value if needed
            last_timestep = new_timestep

len(fill_steps)

# Check that no duplicates in time steps
#duplicates = False
#for i in collections.Counter(fill_steps):
#    if(collections.Counter(fill_steps)[i] > 1):
#        duplicates = True

#print(duplicates)
#list(map(lambda x: x if x[0] else '', collections.Counter(fill_steps)))
# Out:
# 192

# %%
# Check that no duplicates in source data
#dup = False
#count_dt = collections.Counter(air_quality['dt'])
#for i in count_dt:
#    if(count_dt[i] > 1):
#        dup = True

#print(dup)

# %%
# Create dataframe from filled timesteps
fill_df = pd.DataFrame(data=fill_steps, columns=['dt'])

# Join new timestamps to dataframe
aq_join_fill = air_quality.merge(right=fill_df, on='dt', how='outer', suffixes=['', '_join'])

# Examine missing data after join
aq_join_fill[aq_join_fill['components_pm2_5'].isna()].head()
# Out:
#                        dt  main_aqi  components_co  components_no  \
# 18200 2021-01-27 01:00:00       NaN            NaN            NaN
# 18201 2021-01-27 02:00:00       NaN            NaN            NaN
# 18202 2021-01-27 03:00:00       NaN            NaN            NaN
# 18203 2021-01-27 04:00:00       NaN            NaN            NaN
# 18204 2021-01-27 05:00:00       NaN            NaN            NaN
#
#        components_no2  components_o3  components_so2  components_pm2_5  \
# 18200             NaN            NaN             NaN               NaN
# 18201             NaN            NaN             NaN               NaN
# 18202             NaN            NaN             NaN               NaN
# 18203             NaN            NaN             NaN               NaN
# 18204             NaN            NaN             NaN               NaN
#
#        components_pm10  components_nh3
# 18200              NaN             NaN
# 18201              NaN             NaN
# ...

# %%
# Check that no duplicates in first join
#dup = False
#count_dt = collections.Counter(aq_join_fill['dt'])
#for i in count_dt:
#    if(count_dt[i] > 1):
#        dup = True

#print(dup)

# %%
# Create copy of dt col before setting dt index so we don't lose time data
# Create DateTime index
aq_join_fill['DateTime'] = aq_join_fill['dt']
aq_join_fill_dt = aq_join_fill.set_index('dt')
#print(aq_join_fill.head())

# Average values for each day & hour to fill in missing values in the time series
averages = aq_join_fill_dt.groupby(
    [
        aq_join_fill_dt.index.strftime('%m'), # Pad dates to avoid duplicates
        aq_join_fill_dt.index.strftime('%d'), 
        aq_join_fill_dt.index.strftime('%H')]).mean()
        
#averages.shape
#print(averages.head())
#Check if PM2.5 data has nulls after averaging
print('NAs in PM2.5 data after averaging over time: ', averages['components_pm2_5'].isna().sum())
# Out:
# NAs in PM2.5 data after averaging over time:  0
# /var/folders/bx/8_p36bpd14nckr66rq2kk6kc0000gn/T/ipykernel_3788/1078082750.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   aq_join_fill_dt.index.strftime('%H')]).mean()

# %%
# Prep tables for join
averages['m_d_h'] = averages.index.map(lambda x: str(x[0]) + str(x[1]) + str(x[2]))
#any(averages.duplicated(subset=['m_d_h']))
aq_join_fill_dt['m_d_h'] = aq_join_fill_dt.index.map(lambda x: x.strftime('%m') + x.strftime('%d') + x.strftime('%H'))
averages.head()
#aq_join_fill_dt.head()
# Out:
#           main_aqi  components_co  components_no  components_no2  \
# dt dt dt
# 01 01 00       1.5        363.825          0.010          12.040
#       01       1.5        367.165          0.485          11.225
#       02       2.0        365.495          1.380          10.455
#       03       2.0        378.850          2.245          12.210
#       04       2.0        437.260          5.655          15.060
#
#           components_o3  components_so2  components_pm2_5  components_pm10  \
# dt dt dt
# 01 01 00         52.570           6.695            11.065           14.460
#       01         53.640           6.500            11.760           15.430
#       02         55.075           7.315            11.615           15.565
#       03         54.005          11.965            12.535           17.165
#       04         61.870          28.610            13.110           18.350
#
#           components_nh3   m_d_h
# dt dt dt
# 01 01 00          16.020  010100
# ...

# %%
# Join averages to time series
#print(aq_join_fill_dt.shape)
aq_averaged = aq_join_fill_dt.merge(right=averages, how='left', on = 'm_d_h', suffixes= ('', '_avg'))
#aq_averaged.reset_index(drop=True, inplace=True)
# Check duplicates
print(f'Has duplicate dates? {any(aq_averaged["DateTime"].duplicated())}')

# Check which dates have missing data
missing_data = aq_averaged[aq_averaged['components_co'].isna()]['DateTime'].to_list() 
print(f'Null dates match initial gap filling? {missing_data == fill_steps}\n# Missing records: {len(missing_data)}')
# Out:
# Has duplicate dates? False
# Null dates match initial gap filling? True
# # Missing records: 192

# %%
# Compile original data column names
data_cols = [
    'main_aqi',
    'components_co', 
    'components_no', 
    'components_no2',
    'components_o3',
    'components_so2',
    'components_pm2_5',
    'components_pm10',
    'components_nh3']

# Update missing values with joined data
for col_name in data_cols:
    aq_averaged[col_name] = aq_averaged[col_name].where(aq_averaged[col_name].notnull(), aq_averaged[col_name + '_avg'])


# Check that all NAs have been removed from PM2pt5 data
print(f'Number of missing records: {aq_averaged["components_pm2_5"].isna().sum()}')
# Out:
# Number of missing records: 0

# %%
# Extract only columns of interest
data_cols.insert(0, 'DateTime')
aq_averaged = aq_averaged[data_cols]
aq_averaged.head()
# Out:
#              DateTime  main_aqi  components_co  components_no  components_no2  \
# 0 2020-11-25 01:00:00       1.0         236.99           0.60            3.56
# 1 2020-11-25 02:00:00       1.0         233.65           0.92            2.87
# 2 2020-11-25 03:00:00       1.0         223.64           0.91            2.16
# 3 2020-11-25 04:00:00       1.0         213.62           0.64            1.54
# 4 2020-11-25 05:00:00       1.0         210.29           0.60            1.56
#
#    components_o3  components_so2  components_pm2_5  components_pm10  \
# 0          66.52            1.97              7.08             8.78
# 1          65.80            1.91              6.16             7.67
# 2          63.66            1.62              4.53             5.74
# 3          67.23            2.71              2.81             3.43
# 4          69.38            3.58              2.30             2.70
#
#    components_nh3
# 0           17.73
# 1           16.97
# 2           13.81
# ...

# %%
# Plot data over time
aq_by_month = aq_averaged.copy()
aq_by_month['year'] = aq_by_month['DateTime'].map(lambda x: x.year)
aq_by_month['month'] = aq_by_month['DateTime'].map(lambda x: x.month)
aq_by_month['year_month'] = aq_by_month['DateTime'].map(lambda x: x.strftime('%Y-%m'))
aq_by_month.head()
sns.lineplot(x='year_month', y='components_pm2_5', hue='year', data=aq_by_month)
# Out:
# <AxesSubplot: xlabel='year_month', ylabel='components_pm2_5'>

# %%
# Plot by month:
# Note that: for the two years of data, fire season seems to have had worst monthly air quality for the second year
# Potential increasing trend as well as seasonabl trend
sns.lineplot(x='month', y='components_pm2_5', hue='year', data=aq_by_month)
# Out:
# <AxesSubplot: xlabel='month', ylabel='components_pm2_5'>

# %%
# Transform time series to stationary:
# Create a differenced series to remove any increasing trend
def difference(dataset, interval=1):
    diff = [None] * interval # Start with null value(s) so length matches the other data frames
    # Iterate through 1 - n records
    for i in range(interval, len(dataset)):
        # Calculate difference between current and timestep and past timestep
        value = dataset[i] - dataset[i - interval]
        diff.append(value)

    return pd.Series(diff)

aq_differenced = difference(dataset=aq_by_month['components_pm2_5'])

# Add the differenced data back to the original data frame
aq_by_month['pm2_5_lag1'] = aq_differenced

# Plot the differenced data over time
sns.lineplot(x=aq_by_month['year_month'], y=aq_by_month['pm2_5_lag1'], hue=aq_by_month['year'])
# Out:
# <AxesSubplot: xlabel='year_month', ylabel='pm2_5_lag1'>

# %%
#Plot the differenced data by month
# There are still some seasonal variations, but there isn't enough data 
# to seasonally differenc the whole
sns.lineplot(x=aq_by_month['month'], y=aq_by_month['pm2_5_lag1'], hue=aq_by_month['year'])
# Out:
# <AxesSubplot: xlabel='month', ylabel='pm2_5_lag1'>

# %%
# (Transforming data to stationary cont'd)
# 2. Apply seasonal lag to remove variations due to winter and summer (eg fire season)
aq_differenced_1year = difference(dataset=aq_by_month['pm2_5_lag1'], interval = 365*24)

# Add the differenced data back to the original data frame
aq_by_month['pm2_5_lag1_lagYr'] = aq_differenced_1year

# Plot the differenced data over time
# Removes some of the variation but does not appear to make a substantial difference
# For now, we will proceed with the first differenced data of lag=1
sns.lineplot(x=aq_by_month['year_month'].iloc[365*24:], y=aq_by_month['pm2_5_lag1_lagYr'].iloc[365*24:], hue=aq_by_month['year'])
# Out:
# <AxesSubplot: xlabel='year_month', ylabel='pm2_5_lag1_lagYr'>

# %%
# Frame a sequence as a supervised learning problem
def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    # Shift current values by lag value (eg shift forward one timestep)
    columns = [df.shift(i) for i in range(1, lag+1)]
    # Add the shifted records to the bottom of the original timeseries
    columns.append(df)
    # Concatenate the shifted records with the original timeseries side by side,
    # but shifted forward by the given timestep
    # Eg
    # Col1  Col2
    # T     T+1
    # T+1   T+2 etc
    df = pd.concat(columns, axis=1)
    # Remove the first row of nulls 
    # (because both time series have a missing first record)
    df = df.drop(0)
    return df

# %%
# Scale train and test data to [-1, 1]
def scale(train, test):
    # fit scaler
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler = scaler.fit(train)
    # transform train (possibly not needed for 1d timeseries)
    train = train.reshape(train.shape[0], train.shape[1])
    train_scaled = scaler.transform(train)
    # transform test
    test = test.reshape(test.shape[0], test.shape[1])
    test_scaled = scaler.transform(test)
    return scaler, train_scaled, test_scaled
 
# inverse scaling for a forecasted value
def invert_scale(scaler, X, yhat):
    new_row = [x for x in X] + [yhat]
    array = np.array(new_row)
    array = array.reshape(1, len(array))
    inverted = scaler.inverse_transform(array)
    return inverted[0, -1]

# %%
# Evaluate the model on a dataset, returns RMSE in transformed units
def evaluate(model, raw_data, scaled_dataset, scaler, offset, batch_size):
    # separate
    X, y = scaled_dataset[:,0:-1], scaled_dataset[:,-1]
    # reshape
    reshaped = X.reshape(len(X), 1, 1)
    # forecast dataset
    output = model.predict(reshaped, batch_size=batch_size)
    # invert data transforms on forecast
    predictions = list()
    
    for i in range(len(output)):
        yhat = output[i,0]
        # invert scaling
        yhat = invert_scale(scaler, X[i], yhat)
        # invert differencing
        yhat = yhat + raw_data[i]
        # store forecast
        predictions.append(yhat)
        
    # report performance
    rmse = np.sqrt(mean_squared_error(raw_data[1:], predictions))
    return rmse

# %%
# Load dataset
series = aq_by_month['components_pm2_5']

# transform data to be stationary
raw_values = series.values
print(len(raw_values))
diff_values = difference(raw_values, 1)

# transform data to be supervised learning
supervised = timeseries_to_supervised(diff_values, 1)
supervised_values = supervised.values

#Define train split
#train_split = 0.8 # For 80/20 test/train split

train_n, test_n = 14702, 3688 # Close to 80/20 split but still divisible by batch size

# split data into train and test-sets
#train_n = int(len(supervised_values) * train_split) - 1
train, test = supervised_values[0:train_n], supervised_values[train_n + 1:]

# transform the scale of the data
scaler, train_scaled, test_scaled = scale(train, test)

# fit and evaluate model
train_trimmed = train_scaled[2:, :]

# Check n samples in train and test data
train_len, test_len = train_trimmed.shape[0], test_scaled.shape[0]
print(train_len, test_len)
# Out:
# 18392
# 14700 3688

# %%
# Fit an LSTM network to training data
def fit_lstm(train, test, raw, scaler, batch_size, nb_epoch, neurons, learning_rate=0.001, reg=l2(0.1)):
    X, y = train[:, 0:-1], train[:, -1]
    X = X.reshape(X.shape[0], 1, X.shape[1])
    # prepare model
    model = Sequential()
    # batch_input_shape = (numberOfSequence, timesteps, data shape) (deprecated)
    model.add(
        LSTM(
            neurons, 
            batch_input_shape=(batch_size, X.shape[1], X.shape[2]), # Need batch input shape for stateful
            stateful=True,
            kernel_regularizer=reg))
    model.add(Dense(1))
    # Specify learning rate for updating weights
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(loss='mean_squared_error', optimizer=optimizer)

    # Create lists to store training RMSE and test RMSE values
    train_rmse, test_rmse = list(), list()

    # Iterate over all epochs
    for i in range(nb_epoch):
        # Fit model
        model.fit(X, y, epochs=1, batch_size=batch_size, verbose=0, shuffle=False)
        model.reset_states()

        # Evaluate model on training data
        train_plus_test_len = len(train) + len(test) + 1 # Make sure to add one because we are indexing from the end
        test_len = len(test)
        raw_train = raw[-train_plus_test_len: -test_len]
        train_rmse.append(evaluate(model, raw_train, train, scaler, 0, batch_size))
        model.reset_states()

        # Evaluate model on test data
        raw_test = raw[-(len(test)+1):]
        test_rmse.append(evaluate(model, raw_test, test, scaler, 0, batch_size))
        model.reset_states()
        
    # Create dataframe to store RMSE results
    history = pd.DataFrame()
    history['train'], history['test'] = train_rmse, test_rmse
        
    return history

# %%
# Evaluate effect of learning rate:

# Set parameters for model runs
#repeats = 10
#repeats = 1
n_batch = 4 # Note: Number of train and test samples must be divisible by the batch size
n_epochs = 25 #was 500, takes 15 m with 10 epochs
n_neurons = 50 # Was 1
learning_rates = [0.000001, 0.00001, 0.0001, 0.001] # 0.0001 seems to be the best learning rate so far 
# UPDATE: It seems that the number of epochs was far too low to evaluate the effect of the learning rate, and the learning rate was too high,
# thereby causing the weights to be updated past their optimal value and then 'explode' around 200 epochs
regularizer = l2(0.1)
train_colors = ['green', 'blue', 'purple', 'pink']
test_colors = ['brown', 'red', 'orange', 'yellow']

# Run diagnostic experiments
def run():
    # run diagnostic tests
    #for i in range(repeats):
    for i, rate in enumerate(learning_rates):
        history = fit_lstm(
            train=train_trimmed, 
            test=test_scaled, 
            raw=raw_values, 
            scaler=scaler, 
            batch_size=n_batch,
            nb_epoch=n_epochs, 
            neurons=n_neurons,
            learning_rate=rate,
            reg=regularizer)
        plt.plot(history['train'], color=train_colors[i], label=rate)
        plt.plot(history['test'], color=test_colors[i], label=rate)
        legend = plt.legend(loc='upper right')
        print('%d) TrainRMSE=%f, TestRMSE=%f' % (i, history['train'].iloc[-1], history['test'].iloc[-1]))
        plt.savefig(f'model_runs/learning_rate_diagnostic.png')

run()

# %%
# Evaluate effect of number of epochs:

# Set parameters for model runs
#repeats = 10
#repeats = 1
n_batch = 4 # Note: Number of train and test samples must be divisible by the batch size
#n_epochs = 25 #was 500, takes 15 m with 10 epochs
epochs_list = [25, 100, 200, 500] # 25 or 100 seems good
n_neurons = 50 # Was 1
#learning_rates = [0.000001, 0.00001, 0.0001, 0.001] # 0.0001 seems to be the best learning rate so far
learning_rate = 0.0001
regularizer = l2(0.1)
train_colors = ['green', 'blue', 'purple', 'pink']
test_colors = ['brown', 'red', 'orange', 'yellow']

# Run diagnostic experiments
def run():
    # run diagnostic tests
    for i, epochs in enumerate(epochs_list):
        history = fit_lstm(
            train=train_trimmed, 
            test=test_scaled, 
            raw=raw_values, 
            scaler=scaler, 
            batch_size=n_batch,
            nb_epoch=epochs, 
            neurons=n_neurons,
            learning_rate=learning_rate,
            reg=regularizer)
        plt.plot(history['train'], color=train_colors[i], label=epochs)
        plt.plot(history['test'], color=test_colors[i], label=epochs)
        legend = plt.legend(loc='upper right')
        print('%d) TrainRMSE=%f, TestRMSE=%f' % (i, history['train'].iloc[-1], history['test'].iloc[-1]))
        plt.savefig(f'model_runs/epochs_diagnostic.png')

run()

#0) TrainRMSE=7.457439, TestRMSE=8.211168
#1) TrainRMSE=7.582495, TestRMSE=6.391336
#2) TrainRMSE=7.831625, TestRMSE=6.260400

# %%
# Evaluate effect of number of neurons

# Set parameters for model runs
#repeats = 10
#repeats = 1
n_batch = 4 # Note: Number of train and test samples must be divisible by the batch size
n_epochs = 25 #was 500, takes 15 m with 10 epochs
#epochs_list = [25, 100, 200, 500] # 25 or 100 seems good
#n_neurons = 50 # Was 1
neurons_list = [25, 50, 100, 200] # 100 seems to be the best amount of neurons
#learning_rates = [0.000001, 0.00001, 0.0001, 0.001] # 0.0001 seems to be the best learning rate so far
learning_rate = 0.0001
regularizer = l2(0.1)
train_colors = ['green', 'blue', 'purple', 'pink']
test_colors = ['brown', 'red', 'orange', 'yellow']

# Run diagnostic experiments
def run():
    # run diagnostic tests
    for i, neurons in enumerate(neurons_list):
        history = fit_lstm(
            train=train_trimmed, 
            test=test_scaled, 
            raw=raw_values, 
            scaler=scaler, 
            batch_size=n_batch,
            nb_epoch=n_epochs, 
            neurons=neurons,
            learning_rate=learning_rate,
            reg=regularizer)
        plt.plot(history['train'], color=train_colors[i], label=neurons)
        plt.plot(history['test'], color=test_colors[i], label=neurons)
        legend = plt.legend(loc='upper right')
        print('%d) TrainRMSE=%f, TestRMSE=%f' % (i, history['train'].iloc[-1], history['test'].iloc[-1]))
        plt.savefig(f'model_runs/neurons_diagnostic.png')

run()
# Out:
# 2023-01-08 22:42:38.399217: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
# 922/922 [==============================] - 1s 769us/step
# 0) TrainRMSE=7.500974, TestRMSE=8.349249
# ...
# 922/922 [==============================] - 1s 803us/step
# 1) TrainRMSE=7.506317, TestRMSE=8.365674
# ...
# 922/922 [==============================] - 1s 742us/step
# 2) TrainRMSE=7.387785, TestRMSE=7.986188
# ...
# 922/922 [==============================] - 1s 881us/step
# 3) TrainRMSE=7.484980, TestRMSE=8.295710

# %%
# Evaluate effect of regularization (checking lower values just to see...)

# Set parameters for model runs
#repeats = 10
#repeats = 1
n_batch = 4 # Note: Number of train and test samples must be divisible by the batch size
n_epochs = 25 #was 500, takes 15 m with 10 epochs
#epochs_list = [25, 100, 200, 500] # 25 or 100 seems good
n_neurons = 100 # Was 1
#neurons_list = [25, 50, 100, 200] # 100 seems to be the best amount of neurons
#learning_rates = [0.000001, 0.00001, 0.0001, 0.001] # 0.0001 seems to be the best learning rate so far
learning_rate = 0.0001
#regularizer = l2(0.1)
regularizer_list = [0.01, 0.1] # l2(0.1) seems to be the best so far
#train_colors = ['green', 'blue', 'purple', 'pink']
train_colors = ['green', 'blue']
#test_colors = ['brown', 'red', 'orange', 'yellow']
test_colors = ['brown', 'red']
# Run diagnostic experiments
def run():
    # run diagnostic tests
    for i, reg in enumerate(regularizer_list):
        history = fit_lstm(
            train=train_trimmed, 
            test=test_scaled, 
            raw=raw_values, 
            scaler=scaler, 
            batch_size=n_batch,
            nb_epoch=n_epochs, 
            neurons=n_neurons,
            learning_rate=learning_rate,
            reg=l2(reg))
        plt.plot(history['train'], color=train_colors[i], label=reg)
        plt.plot(history['test'], color=test_colors[i], label=reg)
        legend = plt.legend(loc='upper right')
        print('%d) TrainRMSE=%f, TestRMSE=%f' % (i, history['train'].iloc[-1], history['test'].iloc[-1]))
        plt.savefig(f'model_runs/regularizer_diagnostic.png')

run()
# Out:
# ...
# 922/922 [==============================] - 1s 749us/step
# 0) TrainRMSE=7.933020, TestRMSE=6.166424
# ...
# 922/922 [==============================] - 1s 744us/step
# 1) TrainRMSE=7.480374, TestRMSE=8.284290

# %%
# Redefine our fit_lstm function to use a stateless LSTM so that we can have
# batch sizes that are not perfect factors for the shape of our data
# without throwing an error (input_shape will not throw an error but batch_input_shape will)

# Fit an LSTM network to training data
def fit_lstm(train, test, raw, scaler, batch_size, nb_epoch, neurons, learning_rate=0.001, reg=l2(0.1)):
    X, y = train[:, 0:-1], train[:, -1]
    X = X.reshape(X.shape[0], 1, X.shape[1])
    # prepare model
    model = Sequential()
    # batch_input_shape = (numberOfSequence, timesteps, data shape) (deprecated)
    model.add(
        LSTM(
            neurons, 
            input_shape=(X.shape[1], X.shape[2]),
            #batch_input_shape=(batch_size, X.shape[1], X.shape[2]), # Need batch input shape for stateful
            #stateful=True,
            kernel_regularizer=reg))
    model.add(Dense(1))
    # Specify learning rate for updating weights
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(loss='mean_squared_error', optimizer=optimizer)

    # Create lists to store training RMSE and test RMSE values
    train_rmse, test_rmse = list(), list()

    # Iterate over all epochs
    for i in range(nb_epoch):
        # Fit model
        model.fit(X, y, epochs=1, batch_size=batch_size, verbose=0, shuffle=False)

        # Evaluate model on training data
        train_plus_test_len = len(train) + len(test) + 1 # Make sure to add one because we are indexing from the end
        test_len = len(test)
        raw_train = raw[-train_plus_test_len: -test_len]
        train_rmse.append(evaluate(model, raw_train, train, scaler, 0, batch_size))

        # Evaluate model on test data
        raw_test = raw[-(len(test)+1):]
        test_rmse.append(evaluate(model, raw_test, test, scaler, 0, batch_size))
        
    # Create dataframe to store RMSE results
    history = pd.DataFrame()
    history['train'], history['test'] = train_rmse, test_rmse
        
    return history

# %%
# Evaluate effect of batch size

# Set parameters for model runs
#repeats = 10
batch_size_list = [4, 32, 64]
#n_batch = 4 # Note: Number of train and test samples must be divisible by the batch size
#epochs_list = [25, 100, 200, 500] # 25 or 100 seems good
n_epochs = 25 #was 500
#neurons_list = [25, 50, 100, 200] # 100 seems to be the best amount of neurons
n_neurons = 100 # Was 1
#learning_rates = [0.000001, 0.00001, 0.0001, 0.001] # 0.0001 seems to be the best learning rate so far
learning_rate = 0.0001
#regularizer_list = [0.01, 0.1] # l2(0.1) seems to be the best so far
regularizer = l2(0.1)
train_colors = ['green', 'blue', 'purple']
test_colors = ['brown', 'red', 'orange']

# Run diagnostic experiments
def run():
    # run diagnostic tests
    for i, batch_size in enumerate(batch_size_list):
        history = fit_lstm(
            train=train_trimmed, 
            test=test_scaled, 
            raw=raw_values, 
            scaler=scaler, 
            batch_size=batch_size,
            nb_epoch=n_epochs, 
            neurons=n_neurons,
            learning_rate=learning_rate,
            reg=regularizer)
        plt.plot(history['train'], color=train_colors[i], label=batch_size)
        plt.plot(history['test'], color=test_colors[i], label=batch_size)
        legend = plt.legend(loc='upper right')
        print('%d) TrainRMSE=%f, TestRMSE=%f' % (i, history['train'].iloc[-1], history['test'].iloc[-1]))
        plt.savefig(f'model_runs/batch_size_diagnostic.png')

run()
# Out:
# ...
# 922/922 [==============================] - 1s 782us/step
# 0) TrainRMSE=7.506295, TestRMSE=8.361192
# ...
# 116/116 [==============================] - 0s 917us/step
# 1) TrainRMSE=7.509762, TestRMSE=8.376037
# ...
# 58/58 [==============================] - 0s 984us/step
# 2) TrainRMSE=7.511276, TestRMSE=8.381839

# %%
# Redefine our fit_lstm function to allow us to specify dropout rate

# Fit an LSTM network to training data
def fit_lstm(train, test, raw, scaler, batch_size, nb_epoch, neurons, learning_rate=0.001, reg=l2(0.1), dropout=0.0):
    X, y = train[:, 0:-1], train[:, -1]
    X = X.reshape(X.shape[0], 1, X.shape[1])
    # prepare model
    model = Sequential()
    # batch_input_shape = (numberOfSequence, timesteps, data shape) (deprecated)
    model.add(
        LSTM(
            neurons, 
            input_shape=(X.shape[1], X.shape[2]),
            #batch_input_shape=(batch_size, X.shape[1], X.shape[2]), # Need batch input shape for stateful
            #stateful=True,
            kernel_regularizer=reg,
            dropout=dropout))
    model.add(Dense(1))
    # Specify learning rate for updating weights
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(loss='mean_squared_error', optimizer=optimizer)

    # Create lists to store training RMSE and test RMSE values
    train_rmse, test_rmse = list(), list()

    # Iterate over all epochs
    for i in range(nb_epoch):
        # Fit model
        model.fit(X, y, epochs=1, batch_size=batch_size, verbose=0, shuffle=False)

        # Evaluate model on training data
        train_plus_test_len = len(train) + len(test) + 1 # Make sure to add one because we are indexing from the end
        test_len = len(test)
        raw_train = raw[-train_plus_test_len: -test_len]
        train_rmse.append(evaluate(model, raw_train, train, scaler, 0, batch_size))

        # Evaluate model on test data
        raw_test = raw[-(len(test)+1):]
        test_rmse.append(evaluate(model, raw_test, test, scaler, 0, batch_size))
        
    # Create dataframe to store RMSE results
    history = pd.DataFrame()
    history['train'], history['test'] = train_rmse, test_rmse
        
    return history

# %%
# Evaluate effect of dropout rate

# Set parameters for model runs
#repeats = 10
#batch_size_list = [4, 32, 64] # no noticeable difference
batch_size = 4 # Note: Number of train and test samples must be divisible by the batch size
#epochs_list = [25, 100, 200, 500] # 25 or 100 seems good
n_epochs = 25
#neurons_list = [25, 50, 100, 200] # 100 seems to be the best amount of neurons
n_neurons = 100
#learning_rates = [0.000001, 0.00001, 0.0001, 0.001] # 0.0001 seems to be the best learning rate so far
learning_rate = 0.0001
#regularizer_list = [0.01, 0.1] # l2(0.1) seems to be the best so far
regularizer = l2(0.1)
dropout_list = [0.0, 0.2, 0.5] # Dropout rate doesn't seem to make a large difference
#droput = 0.2
train_colors = ['green', 'blue', 'purple']
test_colors = ['brown', 'red', 'orange']

# Run diagnostic experiments
def run():
    # run diagnostic tests
    for i, dropout in enumerate(dropout_list):
        history = fit_lstm(
            train=train_trimmed, 
            test=test_scaled, 
            raw=raw_values, 
            scaler=scaler, 
            batch_size=batch_size,
            nb_epoch=n_epochs, 
            neurons=n_neurons,
            learning_rate=learning_rate,
            reg=regularizer,
            dropout=dropout)
        plt.plot(history['train'], color=train_colors[i], label=dropout)
        plt.plot(history['test'], color=test_colors[i], label=dropout)
        legend = plt.legend(loc='upper right')
        print('%d) TrainRMSE=%f, TestRMSE=%f' % (i, history['train'].iloc[-1], history['test'].iloc[-1]))
        plt.savefig(f'model_runs/dropout_diagnostic.png')

run()
# Out:
# ...
# 922/922 [==============================] - 1s 786us/step
# 0) TrainRMSE=7.507247, TestRMSE=8.365011
# ...
# 922/922 [==============================] - 1s 784us/step
# 1) TrainRMSE=7.510286, TestRMSE=8.377168
# ...
# 922/922 [==============================] - 1s 770us/step
# 2) TrainRMSE=7.508105, TestRMSE=8.368648

# %%
# Run model with the best parameters we have found so far

# Set parameters for model runs
#repeats = 10
#batch_size_list = [4, 32, 64] # no noticeable difference
batch_size = 32 # Note: Number of train and test samples must be divisible by the batch size
#epochs_list = [25, 100, 200, 500] # 25 or 100 seems good
n_epochs = 200 # Actually seems that model is still learning after 100 epochs
#neurons_list = [25, 50, 100, 200] # 100 seems to be the best amount of neurons
n_neurons = 100
#learning_rates = [0.000001, 0.00001, 0.0001, 0.001] # 0.0001 seems to be the best learning rate so far
learning_rate = 0.0001 # Eventual increase in learning rate around 200 epochs suggests that learning rate is too large at that point
#regularizer_list = [0.01, 0.1] # l2(0.1) seems to be the best so far
regularizer = l2(0.1)
#dropout_list = [0.0, 0.2, 0.5] # Dropout rate doesn't seem to make a large difference
dropout = 0.0
#train_colors = ['green', 'blue', 'purple']
#test_colors = ['brown', 'red', 'orange']

history = fit_lstm(
            train=train_trimmed, 
            test=test_scaled, 
            raw=raw_values, 
            scaler=scaler, 
            batch_size=batch_size,
            nb_epoch=n_epochs, 
            neurons=n_neurons,
            learning_rate=learning_rate,
            reg=regularizer,
            dropout=dropout)
            
plt.plot(history['train'], color='blue', label='Training data')
plt.plot(history['test'], color='orange', label='Testing data')
legend = plt.legend(loc='upper right')
print('%d) TrainRMSE=%f, TestRMSE=%f' % (i, history['train'].iloc[-1], history['test'].iloc[-1]))
plt.savefig(f'model_runs/current_model_diagnostic.png')
# Out:
# ...
# 116/116 [==============================] - 0s 1ms/step
# 18199) TrainRMSE=7.516929, TestRMSE=6.592157

# %%
# Run model with the lower learning rate

# Set parameters for model runs
#repeats = 10
#batch_size_list = [4, 32, 64] # no noticeable difference
batch_size = 32 # Note: Number of train and test samples must be divisible by the batch size
#epochs_list = [25, 100, 200, 500] # 25 or 100 seems good
n_epochs = 200 # Actually seems that model is still learning after 100 epochs
#neurons_list = [25, 50, 100, 200] # 100 seems to be the best amount of neurons
n_neurons = 100
#learning_rates = [0.000001, 0.00001, 0.0001, 0.001] # 0.0001 seems to be the best learning rate so far
learning_rate = 0.00001 # Eventual increase in learning rate around 200 epochs suggests that learning rate is too large at that point
#regularizer_list = [0.01, 0.1] # l2(0.1) seems to be the best so far
regularizer = l2(0.1)
#dropout_list = [0.0, 0.2, 0.5] # Dropout rate doesn't seem to make a large difference
dropout = 0.0
#train_colors = ['green', 'blue', 'purple']
#test_colors = ['brown', 'red', 'orange']

history = fit_lstm(
            train=train_trimmed, 
            test=test_scaled, 
            raw=raw_values, 
            scaler=scaler, 
            batch_size=batch_size,
            nb_epoch=n_epochs, 
            neurons=n_neurons,
            learning_rate=learning_rate,
            reg=regularizer,
            dropout=dropout)
            
plt.plot(history['train'], color='blue', label='Training data')
plt.plot(history['test'], color='orange', label='Testing data')
legend = plt.legend(loc='upper right')
print('%d) TrainRMSE=%f, TestRMSE=%f' % (i, history['train'].iloc[-1], history['test'].iloc[-1]))
plt.savefig(f'model_runs/current_model_lowerLR_diagnostic.png')
# Out:
# ...
# 116/116 [==============================] - 0s 1ms/step
# 18199) TrainRMSE=7.512680, TestRMSE=8.387148

# %%
# Run model with the lower learning rate and higher regularization value

# Set parameters for model runs
#repeats = 10
#batch_size_list = [4, 32, 64] # no noticeable difference
batch_size = 32 # Note: Number of train and test samples must be divisible by the batch size
#epochs_list = [25, 100, 200, 500] # 25 or 100 seems good
n_epochs = 200 # Actually seems that model is still learning after 100 epochs
#neurons_list = [25, 50, 100, 200] # 100 seems to be the best amount of neurons
n_neurons = 100
#learning_rates = [0.000001, 0.00001, 0.0001, 0.001] # 0.0001 seems to be the best learning rate so far
learning_rate = 0.00001 # Eventual increase in learning rate around 200 epochs suggests that learning rate is too large at that point
#regularizer_list = [0.01, 0.1] # l2(0.1) seems to be the best so far
regularizer = l2(0.4)
#dropout_list = [0.0, 0.2, 0.5] # Dropout rate doesn't seem to make a large difference
dropout = 0.0
#train_colors = ['green', 'blue', 'purple']
#test_colors = ['brown', 'red', 'orange']

history = fit_lstm(
            train=train_trimmed, 
            test=test_scaled, 
            raw=raw_values, 
            scaler=scaler, 
            batch_size=batch_size,
            nb_epoch=n_epochs, 
            neurons=n_neurons,
            learning_rate=learning_rate,
            reg=regularizer,
            dropout=dropout)
            
plt.plot(history['train'], color='blue', label='Training data')
plt.plot(history['test'], color='orange', label='Testing data')
legend = plt.legend(loc='upper right')
print('%d) TrainRMSE=%f, TestRMSE=%f' % (i, history['train'].iloc[-1], history['test'].iloc[-1]))
plt.savefig(f'model_runs/current_model_lowerLR_higherReg_diagnostic.png')
# Out:
# ...
# 116/116 [==============================] - 0s 866us/step
# 18199) TrainRMSE=7.515895, TestRMSE=8.399341

# %%
# Regularization didn't affect it too much -> run model with the lower learning rate and larger dropout rate

# Set parameters for model runs
#repeats = 10
#batch_size_list = [4, 32, 64] # no noticeable difference
batch_size = 32 # Note: Number of train and test samples must be divisible by the batch size
#epochs_list = [25, 100, 200, 500] # 25 or 100 seems good
n_epochs = 200 # Actually seems that model is still learning after 100 epochs
#neurons_list = [25, 50, 100, 200] # 100 seems to be the best amount of neurons
n_neurons = 100
#learning_rates = [0.000001, 0.00001, 0.0001, 0.001] # 0.0001 seems to be the best learning rate so far
learning_rate = 0.00001 # Eventual increase in learning rate around 200 epochs suggests that learning rate is too large at that point
#regularizer_list = [0.01, 0.1] # l2(0.1) seems to be the best so far
regularizer = l2(0.1)
#dropout_list = [0.0, 0.2, 0.5] # Dropout rate doesn't seem to make a large difference
dropout = 0.4 # Doesn't seem to make a difference
#train_colors = ['green', 'blue', 'purple']
#test_colors = ['brown', 'red', 'orange']

history = fit_lstm(
            train=train_trimmed, 
            test=test_scaled, 
            raw=raw_values, 
            scaler=scaler, 
            batch_size=batch_size,
            nb_epoch=n_epochs, 
            neurons=n_neurons,
            learning_rate=learning_rate,
            reg=regularizer,
            dropout=dropout)
            
plt.plot(history['train'], color='blue', label='Training data')
plt.plot(history['test'], color='orange', label='Testing data')
legend = plt.legend(loc='upper right')
print('%d) TrainRMSE=%f, TestRMSE=%f' % (i, history['train'].iloc[-1], history['test'].iloc[-1]))
plt.savefig(f'model_runs/current_model_lowerLR_higherDropout_diagnostic.png')
# Out:
# ...
# 116/116 [==============================] - 0s 863us/step
# 18199) TrainRMSE=7.511264, TestRMSE=8.381749

# %%
# Run current working version of the model:
# Note: Interestingly, the selection of hyperparameters for number of epochs, batch size, learning rate, and
# optimizer type align exactly with this paper below on predicting air quality using LSTM:
# https://www.sciencedirect.com/science/article/pii/S2665917422001805
# The paper above appears to be use data from
# the Kaggle air quality in India dataset which have the same units as the data from OpenWeather
# API (ug / m3)
# The RMSE values reported in the paper range from ~ (9.5 - 41)
# Therefore, the RMSEs attained below of ~7.5 for training data and ~8.4 for the test data seem fine

# Set parameters for model runs
#batch_size_list = [4, 32, 64] # no noticeable difference
batch_size = 32 # Note: Number of train and test samples must be divisible by the batch size
#epochs_list = [25, 100, 200, 500] # 25 or 100 seems good
n_epochs = 200 # Actually seems that model is still learning after 100 epochs
#neurons_list = [25, 50, 100, 200] # 100 seems to be the best amount of neurons
n_neurons = 100
#learning_rates = [0.000001, 0.00001, 0.0001, 0.001] # 0.0001 seems to be the best learning rate so far
learning_rate = 0.00001 # Eventual increase in learning rate around 200 epochs suggests that learning rate is too large at that point
#regularizer_list = [0.01, 0.1] # l2(0.1) seems to be the best so far
regularizer = l2(0.1)
#dropout_list = [0.0, 0.2, 0.5] # Dropout rate doesn't seem to make a large difference
dropout = 0.0 # Doesn't seem to make a difference

# Fit an LSTM network to training data
def fit_run_lstm(train, test, raw, scaler, batch_size, nb_epoch, neurons, learning_rate=0.001, reg=l2(0.1), dropout=0.0):
    X, y = train[:, 0:-1], train[:, -1]
    X = X.reshape(X.shape[0], 1, X.shape[1])
    # Prepare model
    model = Sequential()
    # Add LSTM layer
    model.add(
        LSTM(
            neurons, 
            input_shape=(X.shape[1], X.shape[2]),
            kernel_regularizer=reg,
            dropout=dropout))
    # Add output layer
    model.add(Dense(1))
    # Specify learning rate for updating weights
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(loss='mean_squared_error', optimizer=optimizer)

    # Create lists to store training RMSE and test RMSE values
    train_rmse, test_rmse = list(), list()
    
    # Fit model
    model.fit(X, y, epochs=nb_epoch, batch_size=batch_size, verbose=0, shuffle=False)

    # Evaluate model on training data
    train_plus_test_len = len(train) + len(test) + 1 # Make sure to add one because we are indexing from the end
    test_len = len(test)
    raw_train = raw[-train_plus_test_len: -test_len]
    train_rmse.append(evaluate(model, raw_train, train, scaler, 0, batch_size))

    # Evaluate model on test data
    raw_test = raw[-(len(test)+1):]
    test_rmse.append(evaluate(model, raw_test, test, scaler, 0, batch_size))

    print(f'Train RMSE: {train_rmse[0]}, Test RMSE: {test_rmse[0]}')   
    # Create dataframe to store RMSE results
    #history = pd.DataFrame()
    #history['train'], history['test'] = train_rmse, test_rmse
        
    return model

# Run the model
current_model = fit_run_lstm(
            train=train_trimmed, 
            test=test_scaled, 
            raw=raw_values, 
            scaler=scaler, 
            batch_size=batch_size,
            nb_epoch=n_epochs, 
            neurons=n_neurons,
            learning_rate=learning_rate,
            reg=regularizer,
            dropout=dropout)

#Train RMSE: 7.510136342283304, Test RMSE: 8.377429851835158
# Out:
# ...
# 116/116 [==============================] - 0s 884us/step
# Train RMSE: 7.510136342283304, Test RMSE: 8.377429851835158

# %%
# Create scaler for Django app that accepts data with one col

# Get differenced values
diff_values_arr = np.array(diff_values)
# Reshape to 2-D numpy array with n rows x 1 col
diff_values_arr = diff_values_arr.reshape(len(diff_values_arr), 1)
# Create and fit MinMaxScaler
train_scaler = MinMaxScaler(feature_range=(-1, 1))
train_scaler = train_scaler.fit(diff_values_arr)
# transform train
#t = train.reshape(train.shape[0], train.shape[1])
#train_scaler.transform(np.array([[-2]]))

# %%
# Save the scaler
scaler_filename = "aqi_scaler.joblib"
joblib.dump(train_scaler, scaler_filename)
# Out:
# ['aqi_scaler.joblib']

# %%
# Save the model
model_filename = "aqi_LSTM.joblib"
joblib.dump(current_model, model_filename)
# Out:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......lstm
# .........cell
# ............vars
# ...............0
# ...............1
# ...............2
# .........vars
# ...metrics
# ......mean
# .........vars
# ............0
# ............1
# ...optimizer
# ......vars
# .........0
# .........1
# .........10
# .........2
# .........3
# .........4
# .........5
# .........6
# .........7
# .........8
# .........9
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-01-09 23:41:51         2284
# metadata.json                                  2023-01-09 23:41:51           64
# variables.h5                                   2023-01-09 23:41:51       510376
# ['aqi_LSTM.joblib']

# %%
# For testing
#load_model = joblib.load(model_filename)
#load_scaler = joblib.load(scaler_filename)
#load_scaler.transform(np.array([[1]]))
#yhat_t = load_model.predict(np.array([[.5]]))
# Out:
# 1/1 [==============================] - 0s 22ms/step

# %%
#TODO: Update model to calculate AQI based on NowCast 12 hour avg: https://usepa.servicenowservices.com/airnow?id=kb_article_view&sys_id=bb8b65ef1b06bc10028420eae54bcb98&spa=1
